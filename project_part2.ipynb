# %%
import numpy as np
import pandas as pd

# %%
user =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv' )

# %%
sessions= pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv' )

# %%
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')

# %%
transactions=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
user.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
user.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
#Join users to transactions, keeping all rows from transactions and only matching rows
#from users (left join) Expected Output:
result = pd.merge(transactions,user ,left_on='UserID',right_on='UserID', how ='left')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
#13. Which transactions have a UserID not in users?
transactions[~transactions['UserID'].isin(user['UserID'])] #using ~ inverts the mask
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %%
#Join users to transactions, keeping only rows from transactions and users that match
pd.merge(transactions,user, on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
#Join users to transactions, displaying all matching rows AND all non-matching rows
#(full outer join)
pd.merge(user,transactions, how='outer')
# Out:
#     UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0      1.0   Charles    male  2012-12-21         NaN            4.0
# 1      2.0     Pedro    male  2010-08-01  2010-08-08            5.0
# 2      2.0     Pedro    male  2010-08-01  2010-08-08            6.0
# 3      3.0  Caroline  female  2012-10-23  2016-06-07            2.0
# 4      3.0  Caroline  female  2012-10-23  2016-06-07            3.0
# 5      3.0  Caroline  female  2012-10-23  2016-06-07            7.0
# 6      3.0  Caroline  female  2012-10-23  2016-06-07           10.0
# 7      4.0   Brielle  female  2013-07-17         NaN            NaN
# 8      5.0  Benjamin    male  2010-11-25         NaN            NaN
# 9      7.0       NaN     NaN         NaN         NaN            1.0
# 10     7.0       NaN     NaN         NaN         NaN            9.0
# 11     NaN       NaN     NaN         NaN         NaN            8.0
#
#    TransactionDate  ProductID  Quantity
# 0       2012-08-26        2.0       3.0
# ...

# %%
#Determine which sessions occurred on the same day each user registered
pd.merge(sessions,user,left_on='SessionDate',right_on='Registered')
# Out:
#    SessionID SessionDate  UserID_x  UserID_y      User  Gender  Registered  \
# 0          2  2010-08-01         2         2     Pedro    male  2010-08-01
# 1          3  2010-11-25         2         5  Benjamin    male  2010-11-25
# 2          6  2012-10-23         4         3  Caroline  female  2012-10-23
# 3          7  2012-12-21         3         1   Charles    male  2012-12-21
# 4          9  2013-07-17         4         4   Brielle  female  2013-07-17
#
#     Cancelled
# 0  2010-08-08
# 1         NaN
# 2  2016-06-07
# 3         NaN
# 4         NaN

# %%
#Build a dataset with every possible (UserID, ProductID) pair (cross join)
user['key'] =0
products['key']=0

# %%
pd.merge(user, products, on='key')[['UserID', 'ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
#Determine how much quantity of each product was purchased by each user
data =pd.merge(user, products, how='left', on='key')

# %%
data.groupby('ProductID').count
# Out:
# <bound method DataFrameGroupBy.count of <pandas.core.groupby.groupby.DataFrameGroupBy object at 0x00000013AFCD8630>>

# %%
data=pd.merge(user, products, on='key')[['UserID', 'ProductID']].groupby('ProductID')

# %%
data.count()
# Out:
#            UserID
# ProductID
# 1               5
# 2               5
# 3               5
# 4               5
# 5               5

# %%
#pd.merge(transactions, transactions, on='UserID')
pd.merge(transactions, transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %%
#Join each user to his/her first occuring transaction in the transactions table 
pd.merge(user, transactions.groupby('UserID').first().reset_index(), how='left', on='UserID')
# Out:
#    UserID      User  Gender  Registered   Cancelled  key  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN    0            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08    0            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07    0            2.0
# 3       4   Brielle  female  2013-07-17         NaN    0            NaN
# 4       5  Benjamin    male  2010-11-25         NaN    0            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %%
#Test to see if we can drop columns
data = pd.merge(user, transactions.groupby('UserID').first().reset_index(), how='left', on='UserID')

# %%
my_columns = list(data.columns)

# %%
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'key',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
list(data.dropna(thresh=int(data.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered', 'key']

# %%
missing_column = list(data.columns[data.isnull().any()])

# %%
num_missing = data[data[col].isnull() == True].shape[0]

# %%
print('number_missing for column {}: {}'.format(col, num_missing))
# Out:
# number_missing for column ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']: 5

# %%
for col in missing_column:
    num_missing = data[data[col].isnull() == True].shape[0]

# %%
for col in missing_column:
    print('number_missing for column {}: {}'.format(col, num_missing))
# Out:
# number_missing for column Cancelled: 2
# number_missing for column TransactionID: 2
# number_missing for column TransactionDate: 2
# number_missing for column ProductID: 2
# number_missing for column Quantity: 2

# %%
#count of missing data
for col in missing_column:
    num_missing = data[data[col].isnull() == True].shape[0] 
    print('number missing for column {}: {}'.format(col, num_missing)) 
    for col in missing_column:
        percent_missing = data[data[col].isnull() == True].shape[0] /data.shape[0] 
        print('percent missing for column {}: {}'.format( col,percent_missing))
# Out:
# number missing for column Cancelled: 3
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# percent missing for column TransactionDate: 0.4
# percent missing for column ProductID: 0.4
# percent missing for column Quantity: 0.4
# number missing for column TransactionID: 2
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# percent missing for column TransactionDate: 0.4
# percent missing for column ProductID: 0.4
# percent missing for column Quantity: 0.4
# number missing for column TransactionDate: 2
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# percent missing for column TransactionDate: 0.4
# percent missing for column ProductID: 0.4
# percent missing for column Quantity: 0.4
# number missing for column ProductID: 2
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# ...
