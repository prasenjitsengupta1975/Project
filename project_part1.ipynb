# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 =pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
 df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df1.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
#Change the column name from any of the above file.
df.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df.rename(columns={'Indicator': 'indicator_id'},inplace=True)

# %%
df.head(2)
# Out:
#                        indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#Change the names of multiple columns.
df.rename(columns={'Indicator': 'indicator_id','PUBLISH STATES': 'Publication Status'},inplace=True)

# %%
df.head(2)
# Out:
#                           indicator_id Publication Status  Year WHO region  \
# 0     Life expectancy at birth (years)          Published  1990     Europe
# 1270  Life expectancy at birth (years)          Published  1990     Europe
#
#      World Bank income group  Country         Sex  Display Value  Numeric  \
# 0                High-income  Andorra  Both sexes             77     77.0
# 1270             High-income  Germany        Male             72     72.0
#
#       Low  High  Comments
# 0     NaN   NaN       NaN
# 1270  NaN   NaN       NaN

# %%
df.sort_values('Year',axis=0,ascending=True,inplace=True)

# %%
df.head(5)
# Out:
#                            indicator_id Publication Status  Year WHO region  \
# 0      Life expectancy at birth (years)          Published  1990     Europe
# 1270   Life expectancy at birth (years)          Published  1990     Europe
# 3193   Life expectancy at birth (years)          Published  1990     Europe
# 3194   Life expectancy at birth (years)          Published  1990     Europe
# 3197  Life expectancy at age 60 (years)          Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# ...

# %%
#Arrange multiple column values in ascending order.
df.sort_values(['Year','Display Value'],ascending=[True,True])
# Out:
#                            indicator_id Publication Status  Year  \
# 3071  Life expectancy at age 60 (years)          Published  1990
# 1476  Life expectancy at age 60 (years)          Published  1990
# 1474  Life expectancy at age 60 (years)          Published  1990
# 1813  Life expectancy at age 60 (years)          Published  1990
# 3203  Life expectancy at age 60 (years)          Published  1990
# 577   Life expectancy at age 60 (years)          Published  1990
# 4275  Life expectancy at age 60 (years)          Published  1990
# 1181  Life expectancy at age 60 (years)          Published  1990
# 3079  Life expectancy at age 60 (years)          Published  1990
# 3675  Life expectancy at age 60 (years)          Published  1990
# 991   Life expectancy at age 60 (years)          Published  1990
# 1899  Life expectancy at age 60 (years)          Published  1990
# 2033  Life expectancy at age 60 (years)          Published  1990
# ...

# %%
#Make country as the first column of the dataframe.
df[['Country', 'indicator_id','Publication Status', 'Year', 'WHO region','World Bank income group','Sex', 'Display Value', 'Numeric', 'Low', 'High',
       'Comments']].head(2)
# Out:
#       Country                      indicator_id Publication Status  Year  \
# 0     Andorra  Life expectancy at birth (years)          Published  1990
# 1270  Germany  Life expectancy at birth (years)          Published  1990
#
#      WHO region World Bank income group         Sex  Display Value  Numeric  \
# 0        Europe             High-income  Both sexes             77     77.0
# 1270     Europe             High-income        Male             72     72.0
#
#       Low  High  Comments
# 0     NaN   NaN       NaN
# 1270  NaN   NaN       NaN

# %%
#Get the column array using a variable Expected Output:
df['Country'].values
# Out:
# array(['Andorra', 'Germany', 'Republic of Moldova', ..., 'Cameroon',
#        'Micronesia (Federated States of)', 'Zimbabwe'], dtype=object)

# %%
#df.loc[[11,12,37]]
df.loc[[11,12,37]]
# Out:
#                          indicator_id Publication Status  Year WHO region  \
# 11   Life expectancy at birth (years)          Published  2012     Europe
# 12  Life expectancy at age 60 (years)          Published  2012     Europe
# 37  Life expectancy at age 60 (years)          Published  2012     Europe
#
#    World Bank income group  Country     Sex  Display Value  Numeric  Low  \
# 11             High-income  Austria  Female             83     83.0  NaN
# 12             High-income  Austria  Female             25     25.0  NaN
# 37             High-income   Cyprus  Female             26     26.0  NaN
#
#     High  Comments
# 11   NaN       NaN
# 12   NaN       NaN
# 37   NaN       NaN

# %%
#Get the subset rows excluding 5, 12, 23, and 56
df.drop(df.index[[5,12,23,56]]).head(70)
# Out:
#                            indicator_id Publication Status  Year  \
# 0      Life expectancy at birth (years)          Published  1990
# 1270   Life expectancy at birth (years)          Published  1990
# 3193   Life expectancy at birth (years)          Published  1990
# 3194   Life expectancy at birth (years)          Published  1990
# 3197  Life expectancy at age 60 (years)          Published  1990
# 3199  Life expectancy at age 60 (years)          Published  1990
# 1262  Life expectancy at age 60 (years)          Published  1990
# 1259   Life expectancy at birth (years)          Published  1990
# 3203  Life expectancy at age 60 (years)          Published  1990
# 1273  Life expectancy at age 60 (years)          Published  1990
# 3204   Life expectancy at birth (years)          Published  1990
# 1247  Life expectancy at age 60 (years)          Published  1990
# 3219  Life expectancy at age 60 (years)          Published  1990
# ...
